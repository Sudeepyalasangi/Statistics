# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np

# %%
#pip install scipy

# %%
from scipy import stats

# %%
x = [99, 86, 88, 88, 111, 86, 103, 77, 94, 78, 77, 85, 86]

# %%
np.mean(x)
# Out:
# np.float64(89.07692307692308)

# %%
np.median(x)
# Out:
# np.float64(86.0)

# %%
stats.mode(x)
# Out:
# ModeResult(mode=np.int64(86), count=np.int64(3))

# %%
np.std(x)
# Out:
# np.float64(9.840743705959959)

# %%
np.var(x)
# Out:
# np.float64(96.84023668639053)

# %%
age = [5, 31, 43, 48, 50, 41, 7, 11, 15, 39, 80, 82, 32, 2, 8, 6, 25, 36, 27, 61, 31]

# %%
sorted(age)
# Out:
# [2, 5, 6, 7, 8, 11, 15, 25, 27, 31, 31, 32, 36, 39, 41, 43, 48, 50, 61, 80, 82]

# %%
q1= np.percentile(age,25)

# %%
q1
# Out:
# np.float64(11.0)

# %%
q3= np.percentile(age,75)

# %%
q3
# Out:
# np.float64(43.0)

# %%
q2= np.percentile(age,50)

# %%
q2
# Out:
# np.float64(31.0)

# %%
IQR = q3-q1
IQR
# Out:
# np.float64(32.0)

# %%
lower_fence = q1-(1.5*IQR)
lower_fence
# Out:
# np.float64(-37.0)

# %%
upper_fence = q3+(1.5*IQR)
upper_fence
# Out:
# np.float64(91.0)
